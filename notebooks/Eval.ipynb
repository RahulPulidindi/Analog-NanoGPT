# %%
# !pip install -q condacolab
import condacolab
condacolab.install()

# !mamba create -n py310 python=3.10 -y
# Out:
# ⏬ Downloading https://github.com/jaimergp/miniforge/releases/download/24.11.2-1_colab/Miniforge3-colab-24.11.2-1_colab-Linux-x86_64.sh...
# 📦 Installing...
# 📌 Adjusting configuration...
# 🩹 Patching environment...
# ⏲ Done in 0:00:13
# 🔁 Restarting kernel...
#
# Looking for: ['python=3.10']
#
# [+] 0.0s
# conda-forge/linux-64  ⣾  [+] 0.1s
# conda-forge/linux-64   1%
# conda-forge/noarch    ⣾  [+] 0.2s
# conda-forge/linux-64   6%
# conda-forge/noarch     7%[+] 0.3s
# conda-forge/linux-64  15%
# conda-forge/noarch    30%[+] 0.4s
# conda-forge/linux-64  22%
# conda-forge/noarch    38%[+] 0.5s
# conda-forge/linux-64  26%
# conda-forge/noarch    55%[+] 0.6s
# conda-forge/linux-64  34%
# conda-forge/noarch    72%[+] 0.7s
# conda-forge/linux-64  43%
# conda-forge/noarch    92%conda-forge/noarch
# [+] 0.8s
# conda-forge/linux-64  55%[+] 0.9s
# conda-forge/linux-64  64%[+] 1.0s
# conda-forge/linux-64  72%[+] 1.1s
# conda-forge/linux-64  79%[+] 1.2s
# conda-forge/linux-64  84%[+] 1.3s
# ...

# %%
# !conda run -n py310 python --version
# Out:
# Python 3.10.17

# %%
# !git clone https://github.com/Andrei-Aksionov/nanoGPTplus.git
# Out:
# Cloning into 'nanoGPTplus'...
# remote: Enumerating objects: 342, done.
# remote: Counting objects: 100% (162/162), done.
# remote: Compressing objects: 100% (110/110), done.
# remote: Total 342 (delta 92), reused 55 (delta 51), pack-reused 180 (from 1)
# Receiving objects: 100% (342/342), 649.19 KiB | 2.08 MiB/s, done.
# Resolving deltas: 100% (159/159), done.

# %%
# %cd /content
# Out:
# /content

# %%
# !conda run -n py310 pip install torch==2.4.1
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 797.1/797.1 MB 31.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 410.6/410.6 MB 37.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.1/14.1 MB 162.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.7/23.7 MB 182.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 823.6/823.6 kB 48.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 29.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 121.6/121.6 MB 66.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.5/56.5 MB 61.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 124.2/124.2 MB 65.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 196.0/196.0 MB 72.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 176.2/176.2 MB 71.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 209.4/209.4 MB 72.5 MB/s eta 0:00:00
# ...

# %%
# !conda run -n py310 pip install numpy==2.2.5
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.4/16.4 MB 134.1 MB/s eta 0:00:00
# ...

# %%
# %cd /content/nanoGPTplus/
# Out:
# /content/nanoGPTplus

# %%
# !conda run -n py310 pip install -e .
# Out:
# Obtaining file:///content/nanoGPTplus
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Checking if build backend supports build_editable: started
#   Checking if build backend supports build_editable: finished with status 'done'
#   Getting requirements to build editable: started
#   Getting requirements to build editable: finished with status 'done'
#   Preparing editable metadata (pyproject.toml): started
#   Preparing editable metadata (pyproject.toml): finished with status 'done'
# ...
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.8/11.8 MB 111.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.6/5.6 MB 139.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.6/6.6 MB 146.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 87.6 MB/s eta 0:00:00
# ...

# %%
# %cd /content/
# Out:
# /content

# %%
# !conda install -n py310 -y -c conda-forge aihwkit-gpu
# Out:
# Channels:
#  - conda-forge
# Platform: linux-64
# done
# done
#
#
# ==> WARNING: A newer version of conda exists. <==
#     current version: 24.11.2
#     latest version: 25.3.1
#
# Please update conda by running
#
#     $ conda update -n base -c conda-forge conda
#
#
#
# ## Package Plan ##
#
#   environment location: /usr/local/envs/py310
#
#   added / updated specs:
#     - aihwkit-gpu
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     _openmp_mutex-4.5          |       3_kmp_llvm           7 KB  conda-forge
#     aihwkit-gpu-0.9.2          |  py310hbb5bab1_0        86.1 MB  conda-forge
#     brotli-python-1.1.0        |  py310hf71b8c6_2         341 KB  conda-forge
#     certifi-2025.4.26          |     pyhd8ed1ab_0         154 KB  conda-forge
#     cffi-1.17.1                |  py310h8deb56e_0         238 KB  conda-forge
# ...

# %%
# !conda run -n py310 ls
# Out:
# Analog_NanoGPT_4_64_512_best.pt
# condacolab_install.log
# Digital_NanoGPT_4_64_512_best.pt
# eval.py
# nanoGPTplus
# sample_data

# %%
# Digital Model Eval: 2, 128, 256
# !conda run -n py310 python eval.py
# Out:
# Initializing model with config: {'vocab_size': 50257, 'embeddings_size': 256, 'context_size': 128, 'head_size': None, 'num_heads': 2, 'feed_forward_scaling': 2, 'num_layers': 4, 'bias': True, 'dropout': 0.1}
# Loading checkpoint from: /content/Digital_NanoGPT_2_128_256.pt
# Perplexity:         288.58
#
# 2025-05-10 03:46:06.281 | DEBUG    | src.model.gpt_language_model.gpt:__init__:115 - GPT language model is created with number of parameters: 14.97 million
# ...

# %%
# Analog Model Eval: 2, 128, 256
# !conda run -n py310 python eval.py
# Out:
# Initializing model with config: {'vocab_size': 50257, 'embeddings_size': 256, 'context_size': 64, 'head_size': None, 'num_heads': 4, 'feed_forward_scaling': 2, 'num_layers': 4, 'bias': True, 'dropout': 0.1}
# Loading checkpoint from: /content/Analog_NanoGPT_2_128_256.pt
#
# 2025-05-10 03:57:58.172 | DEBUG    | src.model.gpt_language_model.gpt:__init__:115 - GPT language model is created with number of parameters: 14.97 million
# ...

# %%
# Digital Model Eval: 4, 64, 256
# !conda run -n py310 python eval.py
# Out:
# Initializing model with config: {'vocab_size': 50257, 'embeddings_size': 256, 'context_size': 64, 'head_size': None, 'num_heads': 4, 'feed_forward_scaling': 2, 'num_layers': 4, 'bias': True, 'dropout': 0.1}
# Loading checkpoint from: /content/Analog_NanoGPT_4_64_256.pt
# Perplexity:         94.23
#
# 2025-05-10 05:09:15.832 | DEBUG    | src.model.gpt_language_model.gpt:__init__:115 - GPT language model is created with number of parameters: 14.97 million
# ...

# %%
# Analog Model Eval: 4, 64, 256
# !conda run -n py310 python eval.py
# Out:
# Initializing model with config: {'vocab_size': 50257, 'embeddings_size': 256, 'context_size': 64, 'head_size': None, 'num_heads': 4, 'feed_forward_scaling': 2, 'num_layers': 4, 'bias': True, 'dropout': 0.1}
# Loading checkpoint from: /content/Analog_NanoGPT_4_64_256.pt
# Perplexity:         94.42
#
# 2025-05-10 05:13:04.954 | DEBUG    | src.model.gpt_language_model.gpt:__init__:115 - GPT language model is created with number of parameters: 14.97 million
# ...

# %%
# Analog Model Eval: 4, 128, 256 with InferenceRPUConfig
# !conda run -n py310 python eval.py
# Out:
# Initializing model with config: {'vocab_size': 50257, 'embeddings_size': 256, 'context_size': 128, 'head_size': None, 'num_heads': 4, 'feed_forward_scaling': 2, 'num_layers': 4, 'bias': True, 'dropout': 0.1}
# Loading checkpoint from: /content/Analog_NanoGPT_4_128_256_best.pt
# ...
# Perplexity:         463.69
#
# 2025-05-10 18:42:48.979 | DEBUG    | src.model.gpt_language_model.gpt:__init__:115 - GPT language model is created with number of parameters: 14.97 million
# ...

# %%
# Digital Model Eval: 4, 128, 256 with InferenceRPUConfig
# !conda run -n py310 python eval.py
# Out:
# Initializing model with config: {'vocab_size': 50257, 'embeddings_size': 256, 'context_size': 128, 'head_size': None, 'num_heads': 4, 'feed_forward_scaling': 2, 'num_layers': 4, 'bias': True, 'dropout': 0.1}
# Loading checkpoint from: /content/Digital_NanoGPT_4_128_256_best.pt
# Perplexity:         292.98
#
# 2025-05-10 18:46:30.087 | DEBUG    | src.model.gpt_language_model.gpt:__init__:115 - GPT language model is created with number of parameters: 14.97 million
# ...

# %%
# Digital Model Eval: 4, 64, 256 with InferenceRPUConfig
# !conda run -n py310 python eval.py
# Out:
# Initializing model with config: {'vocab_size': 50257, 'embeddings_size': 256, 'context_size': 64, 'head_size': None, 'num_heads': 4, 'feed_forward_scaling': 2, 'num_layers': 4, 'bias': True, 'dropout': 0.1}
# Loading checkpoint from: /content/Digital_NanoGPT_4_64_256_best.pt
# Perplexity:         346.15
#
# 2025-05-10 20:03:08.959 | DEBUG    | src.model.gpt_language_model.gpt:__init__:115 - GPT language model is created with number of parameters: 14.97 million
# ...

# %%
# Analog Model Eval: 4, 64, 256 with InferenceRPUConfig
# !conda run -n py310 python eval.py
# Out:
# Initializing model with config: {'vocab_size': 50257, 'embeddings_size': 256, 'context_size': 64, 'head_size': None, 'num_heads': 4, 'feed_forward_scaling': 2, 'num_layers': 4, 'bias': True, 'dropout': 0.1}
# Loading checkpoint from: /content/Analog_NanoGPT_4_64_256_best.pt
# Perplexity:         395.16
#
# 2025-05-10 20:21:03.299 | DEBUG    | src.model.gpt_language_model.gpt:__init__:115 - GPT language model is created with number of parameters: 14.97 million
# ...

# %%
# Digital Model Eval: 4, 32, 256 with InferenceRPUConfig
# !conda run -n py310 python eval.py
# Out:
# Initializing model with config: {'vocab_size': 50257, 'embeddings_size': 256, 'context_size': 32, 'head_size': None, 'num_heads': 4, 'feed_forward_scaling': 2, 'num_layers': 4, 'bias': True, 'dropout': 0.1}
# Loading checkpoint from: /content/Digital_NanoGPT_4_32_256_best.pt
# Avg Loss:           4.48
# Perplexity:         88.52
#
# 2025-05-10 20:38:31.812 | DEBUG    | src.model.gpt_language_model.gpt:__init__:115 - GPT language model is created with number of parameters: 14.97 million
# ...

# %%
# Analog Model Eval: 4, 32, 256 with InferenceRPUConfig
# !conda run -n py310 python eval.py
# Out:
# Initializing model with config: {'vocab_size': 50257, 'embeddings_size': 256, 'context_size': 32, 'head_size': None, 'num_heads': 4, 'feed_forward_scaling': 2, 'num_layers': 4, 'bias': True, 'dropout': 0.1}
# Loading checkpoint from: /content/Analog_NanoGPT_4_32_256_best.pt
# Avg Loss:           4.78
# Perplexity:         119.32
#
# 2025-05-10 20:46:15.663 | DEBUG    | src.model.gpt_language_model.gpt:__init__:115 - GPT language model is created with number of parameters: 14.97 million
# ...

# %%
# Digital Model Eval: 4, 128, 256 with InferenceRPUConfig that run for 50 epochs
# !conda run -n py310 python eval.py
# Out:
# Initializing model with config: {'vocab_size': 50257, 'embeddings_size': 256, 'context_size': 128, 'head_size': None, 'num_heads': 4, 'feed_forward_scaling': 2, 'num_layers': 4, 'bias': True, 'dropout': 0.1}
# Loading checkpoint from: /content/Digital_NanoGPT_4_128_256_50epochs_best.pt
# Avg Loss:           6.30
# Perplexity:         542.38
#
# 2025-05-10 20:36:28.801 | DEBUG    | src.model.gpt_language_model.gpt:__init__:115 - GPT language model is created with number of parameters: 14.97 million
# ...

# %%
# Digital Model Eval: 8, 128, 256 with InferenceRPUConfig
# !conda run -n py310 python eval.py
# Out:
# Initializing model with config: {'vocab_size': 50257, 'embeddings_size': 256, 'context_size': 128, 'head_size': None, 'num_heads': 8, 'feed_forward_scaling': 2, 'num_layers': 4, 'bias': True, 'dropout': 0.1}
# Loading checkpoint from: /content/Digital_NanoGPT_8_128_256_best.pt
# Avg Loss:           5.72
# Perplexity:         305.27
#
# 2025-05-10 21:11:27.315 | DEBUG    | src.model.gpt_language_model.gpt:__init__:115 - GPT language model is created with number of parameters: 14.97 million
# ...

# %%
# Analog Model Eval: 8, 128, 256 with InferenceRPUConfig
# !conda run -n py310 python eval.py
# Out:
# Initializing model with config: {'vocab_size': 50257, 'embeddings_size': 256, 'context_size': 128, 'head_size': None, 'num_heads': 8, 'feed_forward_scaling': 2, 'num_layers': 4, 'bias': True, 'dropout': 0.1}
# Loading checkpoint from: /content/Analog_NanoGPT_8_128_256_best.pt
# Avg Loss:           6.55
# Perplexity:         699.10
#
# 2025-05-10 21:35:14.122 | DEBUG    | src.model.gpt_language_model.gpt:__init__:115 - GPT language model is created with number of parameters: 14.97 million
# ...

# %%
# Digital Model Eval: 2, 128, 256 with InferenceRPUConfig
# !conda run -n py310 python eval.py
# Out:
# Initializing model with config: {'vocab_size': 50257, 'embeddings_size': 256, 'context_size': 128, 'head_size': None, 'num_heads': 2, 'feed_forward_scaling': 2, 'num_layers': 4, 'bias': True, 'dropout': 0.1}
# Loading checkpoint from: /content/Digital_NanoGPT_2_128_256_best.pt
# Avg Loss:           5.53
# Perplexity:         252.27
#
# 2025-05-10 21:12:20.582 | DEBUG    | src.model.gpt_language_model.gpt:__init__:115 - GPT language model is created with number of parameters: 14.97 million
# ...

# %%
# Analog Model Eval: 2, 128, 256 with InferenceRPUConfig
# !conda run -n py310 python eval.py
# Out:
# Initializing model with config: {'vocab_size': 50257, 'embeddings_size': 256, 'context_size': 128, 'head_size': None, 'num_heads': 2, 'feed_forward_scaling': 2, 'num_layers': 4, 'bias': True, 'dropout': 0.1}
# Loading checkpoint from: /content/Analog_NanoGPT_2_128_256_best.pt
# Avg Loss:           6.32
# Perplexity:         553.74
#
# 2025-05-10 21:59:59.428 | DEBUG    | src.model.gpt_language_model.gpt:__init__:115 - GPT language model is created with number of parameters: 14.97 million
# ...

# %%
# Digital Model Eval: 4, 128, 512 with InferenceRPUConfig
# !conda run -n py310 python eval.py
# Out:
# Initializing model with config: {'vocab_size': 50257, 'embeddings_size': 512, 'context_size': 128, 'head_size': None, 'num_heads': 4, 'feed_forward_scaling': 2, 'num_layers': 4, 'bias': True, 'dropout': 0.1}
# Loading checkpoint from: /content/Digital_NanoGPT_4_128_512_best.pt
# Avg Loss:           6.24
# Perplexity:         511.83
#
# 2025-05-10 21:37:27.228 | DEBUG    | src.model.gpt_language_model.gpt:__init__:115 - GPT language model is created with number of parameters: 34.14 million
# ...

# %%
# Analog Model Eval: 4, 128, 512 with InferenceRPUConfig
# !conda run -n py310 python eval.py
# Out:
# Initializing model with config: {'vocab_size': 50257, 'embeddings_size': 512, 'context_size': 128, 'head_size': None, 'num_heads': 4, 'feed_forward_scaling': 2, 'num_layers': 4, 'bias': True, 'dropout': 0.1}
# Loading checkpoint from: /content/Analog_NanoGPT_4_128_512_best.pt
# Avg Loss:           6.25
# Perplexity:         517.63
#
# 2025-05-12 00:50:38.034 | DEBUG    | src.model.gpt_language_model.gpt:__init__:115 - GPT language model is created with number of parameters: 34.14 million
# ...

# %%
# Digital Model Eval: 4, 128, 128 with InferenceRPUConfig
# !conda run -n py310 python eval.py
# Out:
# Initializing model with config: {'vocab_size': 50257, 'embeddings_size': 128, 'context_size': 128, 'head_size': None, 'num_heads': 4, 'feed_forward_scaling': 2, 'num_layers': 4, 'bias': True, 'dropout': 0.1}
# Loading checkpoint from: /content/Digital_NanoGPT_4_128_128_best.pt
# Avg Loss:           5.30
# Perplexity:         200.27
#
# 2025-05-10 22:02:16.192 | DEBUG    | src.model.gpt_language_model.gpt:__init__:115 - GPT language model is created with number of parameters: 6.96 million
# ...

# %%
# Analog Model Eval: 4, 128, 128 with InferenceRPUConfig
# !conda run -n py310 python eval.py
# Out:
# Initializing model with config: {'vocab_size': 50257, 'embeddings_size': 128, 'context_size': 128, 'head_size': None, 'num_heads': 4, 'feed_forward_scaling': 2, 'num_layers': 4, 'bias': True, 'dropout': 0.1}
# Loading checkpoint from: /content/Analog_NanoGPT_4_128_128_best.pt
# ...
# Avg Loss:           5.67
# Perplexity:         290.77
#
# 2025-05-11 17:15:47.805 | DEBUG    | src.model.gpt_language_model.gpt:__init__:115 - GPT language model is created with number of parameters: 6.96 million
# ...

# %%
# Digital Model Eval: 4, 64, 512 with InferenceRPUConfig
# !conda run -n py310 python eval.py
# Out:
# Initializing model with config: {'vocab_size': 50257, 'embeddings_size': 512, 'context_size': 64, 'head_size': None, 'num_heads': 4, 'feed_forward_scaling': 2, 'num_layers': 4, 'bias': True, 'dropout': 0.1}
# Loading checkpoint from: /content/Digital_NanoGPT_4_64_512_best.pt
# Loss:         5.79
# Perplexity:         328.61
#
# 2025-05-12 04:44:04.286 | DEBUG    | src.model.gpt_language_model.gpt:__init__:115 - GPT language model is created with number of parameters: 34.14 million
# ...

# %%
# Analog Model Eval: 4, 64, 512 with InferenceRPUConfig
# !conda run -n py310 python eval.py
# Out:
# Initializing model with config: {'vocab_size': 50257, 'embeddings_size': 512, 'context_size': 64, 'head_size': None, 'num_heads': 4, 'feed_forward_scaling': 2, 'num_layers': 4, 'bias': True, 'dropout': 0.1}
# Loading checkpoint from: /content/Analog_NanoGPT_4_64_512_best.pt
# Avg Loss:           6.18
# Perplexity:         484.09
#
# 2025-05-12 04:50:29.262 | DEBUG    | src.model.gpt_language_model.gpt:__init__:115 - GPT language model is created with number of parameters: 34.14 million
# ...
